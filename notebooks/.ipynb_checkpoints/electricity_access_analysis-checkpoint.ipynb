# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Show plots inline
# %matplotlib inline

# %%
# Load the raw electricity access data
file_path = "raw_data/electricity_access.csv"  # adjust name if different
df = pd.read_csv(file_path)

# Preview the data
df.head()
# Out:
#   FREQ_ID FREQ_NAME REF_AREA_ID                REF_AREA_NAME  \
# 0       A    Annual         ABW                        Aruba
# 1       A    Annual         AFE  Africa Eastern and Southern
# 2       A    Annual         AFG                  Afghanistan
# 3       A    Annual         AFW   Africa Western and Central
# 4       A    Annual         AGO                       Angola
#
#             INDICATOR_ID                           INDICATOR_NAME  \
# 0  WB_WDI_EG_ELC_ACCS_ZS  Access to electricity (% of population)
# 1  WB_WDI_EG_ELC_ACCS_ZS  Access to electricity (% of population)
# 2  WB_WDI_EG_ELC_ACCS_ZS  Access to electricity (% of population)
# 3  WB_WDI_EG_ELC_ACCS_ZS  Access to electricity (% of population)
# 4  WB_WDI_EG_ELC_ACCS_ZS  Access to electricity (% of population)
#
#   UNIT_MEASURE_ID         UNIT_MEASURE_NAME AGG_METHOD_ID AGG_METHOD_NAME  \
# 0          PT_POP  Percentage of population            _Z  Not Applicable
# ...

# %%
# Out:
#           REF_AREA_NAME  Year  Access_to_Electricity
# 0                 Aruba  1990               100.0000
# 5               Albania  1990               100.0000
# 6               Andorra  1990               100.0000
# 8  United Arab Emirates  1990               100.0000
# 9             Argentina  1990                92.1548

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.lineplot(
    data=df_long[df_long['REF_AREA_NAME'].isin(['Sudan', 'Kenya', 'Nigeria'])],
    x='Year', y='Access_to_Electricity', hue='REF_AREA_NAME'
)

plt.axvline(2010, color='red', linestyle='--')
plt.text(2010.5, 10, 'Kenya ramps up solar investment', fontsize=9, color='red')

plt.title('Access to Electricity (% of Population)')
plt.ylabel('% Population with Electricity')
plt.xlabel('Year')
plt.legend(title='Country')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df_long.to_csv('clean_data/electricity_access_long.csv', index=False)
